# %% [markdown]
# # YOLO
# In yolo (you only look once) we will have B bounding boxes per pixel, and the pixels are large and cover the whole image.
#
# The pixel in which the center of an object lies is responsible for detecting the object.
#
# Each of the bounding boxes output is 5 numbers, (x,y) (the center, not corner) width, height, confidence.
#
# Confidence is a prediction of IOU
#
# Additionally, each cell predicts a probability distribution over class labels.

# %% [markdown]
# # Color module
# We can use my attention mechanism to give some sort of a color module.
#
# Say I have a variable number of colors N, and I want to map to a fixed number M.
#
# We get M convolution filters.
#
# We filter each image with each filter.  This gives an N x M array of images.
#
# We then apply a softmax to it.  We then do matrix multiplication.

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os
import sys
import pickle
import time
import random

# %matplotlib notebook
# %matplotlib widget

seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# Include location of Python source scripts
sys.path.append(os.path.join(os.path.split(os.getcwd())[0],'source'))

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Initalize global variables

# %%
nclasses = 3
dtype = torch.float32
cwd = os.getcwd()
pwd = os.path.join(os.path.split(cwd)[0])

print(f'cwd: {cwd}')
print(f'pwd: {pwd}')
# Out:
# cwd: /home/abenneck/Desktop/yolo_model/examples
# pwd: /home/abenneck/Desktop/yolo_model

# %% [markdown]
# ### Initialize a dataset of simulated images and visualze a GT example

# %%
from yolo_help import GroundTruthDataset

groundtruth = GroundTruthDataset()

# %%
from yolo_help import bbox_to_rectangles, imshow

I,bbox,cl = groundtruth[0]
fig,ax = plt.subplots()
imshow(I,ax,cmap='gray')
polys = bbox_to_rectangles(bbox,fc='none')
polys.set_edgecolor(plt.cm.jet(cl*255//(nclasses-1)))
ax.add_collection(polys)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # The YOLO Model

# %% [markdown]
# ### Variable Input Layer Example

# %%
from yolo_help import VariableInputConv2d


layer = VariableInputConv2d(3)
fig,ax = plt.subplots(1,3)
I,bbox,cls = groundtruth[0]
imshow(I,ax[0])

r = torch.randperm(I.shape[0])
out1 = layer(torch.tensor(I,dtype=dtype)[None]).clone().detach()[0]
out2 = layer(torch.tensor(I,dtype=dtype)[r][None]).clone().detach()[0] 
imshow(out1,ax[1])
imshow(out2,ax[2])
# note the order of components doesn't matter
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Initalize a neural network following the YOLO framework

# %%
from yolo_help import Net

net = Net()

# %% [markdown]
# ### Visualize example output from model

# %%
from yolo_help import convert_data

out = net(torch.tensor(I[None],dtype=dtype))
B = net.B
stride = net.stride

bboxes,data = convert_data(out,B,stride)

fig,ax = plt.subplots()
x = torch.arange(out.shape[-1])*stride + (stride-1)/2
y = torch.arange(out.shape[-2])*stride + (stride-1)/2
YX = torch.stack(torch.meshgrid(y,x,indexing='ij'),0)
ax.imshow(I[0],cmap='gray')
ax.scatter(YX[1].ravel(),YX[0].ravel(),s=1,alpha=0.5)
x = bboxes[...,0]
y = bboxes[...,1]
w = bboxes[...,2]
h = bboxes[...,3]
c = data[...,-1]
predicted_rectangles = bbox_to_rectangles(torch.stack( (x.ravel(),y.ravel(),w.ravel(),h.ravel()) ).T,fc='none',ec='b',alpha=c.clone().detach()*0.5)
ax.add_collection(predicted_rectangles,)

true_rectangles = bbox_to_rectangles(bbox,fc='none',ec='r')
ax.add_collection(true_rectangles,)
fig.legend(['pred_center','pred_bbox','gt_bbox'])
fig.canvas.draw()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Add predicted bounding boxes to above figure

# %%
from yolo_help import get_assignment_inds


# transform the true bounding boxes
# to do this first we need an assignment to a given cell
shape = out.shape
B = net.B

assignment_inds,ious = get_assignment_inds(bboxes,bbox,shape,stride,B)
bboxes_assigned = bboxes[assignment_inds]
x = bboxes_assigned[...,0]
y = bboxes_assigned[...,1]
w = bboxes_assigned[...,2]
h = bboxes_assigned[...,3]
c = data[assignment_inds,-1]
predicted_rectangles = bbox_to_rectangles(torch.stack( (x.ravel(),y.ravel(),w.ravel(),h.ravel()) ).T,fc='none',ec='g',alpha=c.clone().detach())
ax.add_collection(predicted_rectangles,)

# %% [markdown]
# # Model Training

# %%
from yolo_help import train_yolo_model

nepochs = 9854
lr = 1e-4
cls_loss = torch.nn.CrossEntropyLoss(reduction='sum')
resume = True # if True, will load a saved model

modelname = 'modelsave.pt'
optimizername = 'optimizersave.pt'
lossname = 'loss.pt'
outdir_model = os.path.join(cwd,'outputs','models',f'nepochs_{nepochs}')

net = train_yolo_model(nepochs, lr, cls_loss, outdir_model, modelname, optimizername, lossname, verbose=True, resume=resume)
# Out:
# Loaded predefined model from /home/abenneck/Desktop/yolo_model/examples/outputs/models/nepochs_9854/modelsave.pt
# Starting epoch 0
# Starting epoch 1
# Starting epoch 2
# Starting epoch 3
# Starting epoch 4
# Starting epoch 5
# Starting epoch 6
# Starting epoch 7
# Starting epoch 8
# Starting epoch 9
# Starting epoch 10
# Starting epoch 11
# Starting epoch 12
# Starting epoch 13
# Starting epoch 14
# Starting epoch 15
# Starting epoch 16
# Starting epoch 17
# Starting epoch 18
# Starting epoch 19
# Starting epoch 20
# Starting epoch 21
# Starting epoch 22
# Starting epoch 23
# Starting epoch 24
# Starting epoch 25
# Starting epoch 26
# Starting epoch 27
# Starting epoch 28
# Starting epoch 29
# Starting epoch 30
# Starting epoch 31
# Starting epoch 32
# Starting epoch 33
# Starting epoch 34
# Starting epoch 35
# Starting epoch 36
# Starting epoch 37
# Starting epoch 38
# Starting epoch 39
# Starting epoch 40
# Starting epoch 41
# Starting epoch 42
# Starting epoch 43
# Starting epoch 44
# Starting epoch 45
# Starting epoch 46
# Starting epoch 47
# Starting epoch 48
# Starting epoch 49
# Starting epoch 50
# Starting epoch 51
# Starting epoch 52
# Starting epoch 53
# Starting epoch 54
# Starting epoch 55
# Starting epoch 56
# Starting epoch 57
# Starting epoch 58
# Starting epoch 59
# Starting epoch 60
# Starting epoch 61
# Starting epoch 62
# Starting epoch 63
# Starting epoch 64
# Starting epoch 65
# Starting epoch 66
# Starting epoch 67
# Starting epoch 68
# Starting epoch 69
# Starting epoch 70
# Starting epoch 71
# Starting epoch 72
# Starting epoch 73
# Starting epoch 74
# Starting epoch 75
# Starting epoch 76
# Starting epoch 77
# Starting epoch 78
# Starting epoch 79
# Starting epoch 80
# Starting epoch 81
# Starting epoch 82
# Starting epoch 83
# Starting epoch 84
# Starting epoch 85
# Starting epoch 86
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Post-Processing

# %% [markdown]
# ### Filter candidate bboxes (best_bbox_per_cell + NMS)

# %%
from yolo_help import get_best_bounding_box_per_cell
from yolo_post_help import NMS, remove_low_conf_bboxes

def filter_model_outputs(outdir, net, nms_filter = False):
    if not os.path.exists(outdir):
        print(f'Making new directory {outdir}')
        os.makedirs(outdir)
        
    if os.path.exists(os.path.join(outdir, 'all_gt_bbox.pkl')):
        # Save the gt_bbox, pred_bbox, and pred_score info for downstream analysis
        with open(os.path.join(outdir,'all_gt_bbox.pkl'),'rb') as f:
            all_gt_bbox = pickle.load(f)
        with open(os.path.join(outdir,'all_pred_bbox.pkl'),'rb') as f:
            all_pred_bbox = pickle.load(f)
        with open(os.path.join(outdir,'all_scores.pkl'),'rb') as f:
            all_scores = pickle.load(f)
        with open(os.path.join(outdir,'all_images.pkl'),'rb') as f:
            all_images = pickle.load(f)
        print(f'Loaded 4 files from {outdir}')
    else:
        all_pred_bbox = []
        all_scores = []
        all_gt_bbox = []
        all_images = []
        nimages_pq = 10

        groundtruth = GroundTruthDataset(reproducible = True)
        for i, gt in enumerate(groundtruth):
            # Quantify the model's performance against 'nimages_pq' simulated gt images
            if i >= nimages_pq:
                break
                
            # Initialize gt objects (bbox: [cx, cy, w, h, conf])
            I,bbox,cls = gt
            print(f'=== Starting groundtruth[{i}] ({len(bbox)} bboxes) ===')
        
            # Get model outputs for the ith image in the gt dataset
            out = net(torch.tensor(I,dtype=dtype)[None])
            bboxes,data = convert_data(out,net.B,net.stride)
            scores = data[:,-1]
            print(f'{len(bboxes)} bboxes output from model')
            
            # Reduces # of guesses by factor of 2
            start = time.time()
            bboxes_,scores_ = get_best_bounding_box_per_cell(bboxes,scores.clone().detach(),net.B)
            print(f'{len(bboxes_)} bboxes after getting best bbox per cell; Finished in {time.time() - start:.2f}s')
        
            # Remove bounding boxes below some conf threshold
            start = time.time()
            bboxes_, scores_ = remove_low_conf_bboxes(bboxes_, scores_)
            print(f'{len(bboxes_)} bboxes after removing low conf bboxes; Finished in {time.time() - start:.2f}s')
            
            # Perform NMS on filtered guesses (Reduce by a factor of ~2
            if nms_filter:
                start = time.time()
                bboxes_,scores_ = NMS(bboxes_, scores_, nms_threshold = 0.9)
                print(f'{len(bboxes_)} bboxes after NMS; Finished in {time.time() - start:.2f}s\n')
            
            # Append outputs from current image to all outputs for downstream performance quantification and visualization
            all_gt_bbox.append(bbox)
            all_pred_bbox.append(bboxes_)
            all_scores.append(scores_)
            all_images.append(I)
    
        # Save the gt_bbox, pred_bbox, and pred_score info for downstream analysis
        with open(os.path.join(outdir,'all_gt_bbox.pkl'),'wb') as f:
            pickle.dump(all_gt_bbox,f)
        with open(os.path.join(outdir,'all_pred_bbox.pkl'),'wb') as f:
            pickle.dump(all_pred_bbox,f)
        with open(os.path.join(outdir,'all_scores.pkl'),'wb') as f:
            pickle.dump(all_scores,f)
        with open(os.path.join(outdir,'all_images.pkl'),'wb') as f:
            pickle.dump(all_images,f)
        print(f'Saved output .pkl files to {outdir}')

    return all_pred_bbox, all_scores, all_gt_bbox, all_images

# Load filtered outputs, or generate new ones if none exist in outdir
outdir_data = os.path.join(cwd,'outputs','data',f'nepochs_{nepochs}')
all_pred_bbox, all_scores, all_gt_bbox, all_images = filter_model_outputs(outdir_data, net)
# Out:
# === Starting groundtruth[0] (193 bboxes) ===
# 2048 bboxes output from model
# 1024 bboxes after getting best bbox per cell; Finished in 0.00s
# 318 bboxes after removing low conf bboxes; Finished in 0.01s
# === Starting groundtruth[1] (204 bboxes) ===
# 2048 bboxes output from model
# 1024 bboxes after getting best bbox per cell; Finished in 0.00s
# 297 bboxes after removing low conf bboxes; Finished in 0.02s
# === Starting groundtruth[2] (73 bboxes) ===
# 2048 bboxes output from model
# 1024 bboxes after getting best bbox per cell; Finished in 0.00s
# 92 bboxes after removing low conf bboxes; Finished in 0.01s
# === Starting groundtruth[3] (278 bboxes) ===
# 2048 bboxes output from model
# 1024 bboxes after getting best bbox per cell; Finished in 0.00s
# 320 bboxes after removing low conf bboxes; Finished in 0.01s
# === Starting groundtruth[4] (307 bboxes) ===
# 2048 bboxes output from model
# 1024 bboxes after getting best bbox per cell; Finished in 0.00s
# 350 bboxes after removing low conf bboxes; Finished in 0.01s
# === Starting groundtruth[5] (229 bboxes) ===
# 2048 bboxes output from model
# 1024 bboxes after getting best bbox per cell; Finished in 0.00s
# 259 bboxes after removing low conf bboxes; Finished in 0.01s
# === Starting groundtruth[6] (337 bboxes) ===
# 2048 bboxes output from model
# 1024 bboxes after getting best bbox per cell; Finished in 0.00s
# 411 bboxes after removing low conf bboxes; Finished in 0.01s
# === Starting groundtruth[7] (186 bboxes) ===
# 2048 bboxes output from model
# 1024 bboxes after getting best bbox per cell; Finished in 0.00s
# 234 bboxes after removing low conf bboxes; Finished in 0.01s
# === Starting groundtruth[8] (192 bboxes) ===
# 2048 bboxes output from model
# 1024 bboxes after getting best bbox per cell; Finished in 0.00s
# 236 bboxes after removing low conf bboxes; Finished in 0.02s
# === Starting groundtruth[9] (126 bboxes) ===
# 2048 bboxes output from model
# 1024 bboxes after getting best bbox per cell; Finished in 0.00s
# 168 bboxes after removing low conf bboxes; Finished in 0.01s
# Saved output .pkl files to /home/abenneck/Desktop/yolo_model/examples/outputs/data/nepochs_9854

# %% [markdown]
# ### Compare GT bounding boxes with filtered estimated bounding boxes

# %%
nrow = 5
ncol = 2
fig, axs = plt.subplots(nrow, ncol, layout = 'tight')
i,j = 0,0

for idx, I in enumerate(all_images):
    pred_bb = all_pred_bbox[idx]
    pred_s = all_scores[idx]
    gt_bb = all_gt_bbox[idx]

    imshow(I, axs[i,j], cmap = 'gray')
    gt_polys = bbox_to_rectangles(np.asarray(gt_bb),fc='none')
    gt_polys.set_edgecolor('blue')
    axs[i,j].add_collection(gt_polys)
    
    # imshow(I,axs[i,j],cmap='gray')
    pred_polys = bbox_to_rectangles(np.asarray(pred_bb),fc='none')
    pred_polys.set_edgecolor('red')
    axs[i,j].add_collection(pred_polys)

    j += 1

    if j > ncol - 1:
        j = 0
        i += 1

fig.legend(['gt','pred'])
fig.set_size_inches(ncol*3,nrow*3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## PR Curve Generation

# %%
import importlib as imp
import yolo_post_help
imp.reload(yolo_post_help)
from yolo_post_help import compute_pr_curves, plot_pr_curves, get_mAP

out = compute_pr_curves(all_gt_bbox, all_pred_bbox, all_scores, outdir_data, verbose = True)
fig, axs = plot_pr_curves(out)
fig, axs = plot_pr_curves(out, condense = False)
mAP = get_mAP(out)
print(f'mAP: {mAP}')

# TODO: Only compute (p,r) if there is a score below conf_thresh. Otherwise, all tp/fp/fn labels remain the same (Should save <10min on first 10)
# Out:
# ===== Starting iou 0.5 =====
# Starting conf 0.01
# Finished images 1:2 / 10 in 20.38s
# Finished images 3:4 / 10 in 21.27s
# Finished images 5:6 / 10 in 24.19s
# Finished images 7:8 / 10 in 9.78s
# 1784 + 341 = 2125 ?= 2125
# (tp, fp, fn) = (1784, 901, 341) across 10 images
# Finished iter in 78.18s
#
# Starting conf 0.02
# Finished images 1:2 / 10 in 20.27s
# Finished images 3:4 / 10 in 21.18s
# Finished images 5:6 / 10 in 24.26s
# Finished images 7:8 / 10 in 9.89s
# 1784 + 341 = 2125 ?= 2125
# (tp, fp, fn) = (1784, 901, 341) across 10 images
# Finished iter in 78.22s
#
# Starting conf 0.03
# Finished images 1:2 / 10 in 20.42s
# Finished images 3:4 / 10 in 21.20s
# Finished images 5:6 / 10 in 24.20s
# Finished images 7:8 / 10 in 9.74s
# 1784 + 341 = 2125 ?= 2125
# (tp, fp, fn) = (1784, 901, 341) across 10 images
# Finished iter in 78.16s
#
# Starting conf 0.04
# Finished images 1:2 / 10 in 20.37s
# Finished images 3:4 / 10 in 21.32s
# Finished images 5:6 / 10 in 24.29s
# Finished images 7:8 / 10 in 9.76s
# 1784 + 341 = 2125 ?= 2125
# (tp, fp, fn) = (1784, 901, 341) across 10 images
# Finished iter in 78.42s
#
# Starting conf 0.05
# Finished images 1:2 / 10 in 20.47s
# Finished images 3:4 / 10 in 21.27s
# Finished images 5:6 / 10 in 24.19s
# Finished images 7:8 / 10 in 9.93s
# 1784 + 341 = 2125 ?= 2125
# (tp, fp, fn) = (1784, 901, 341) across 10 images
# Finished iter in 78.55s
#
# Starting conf 0.06
# Finished images 1:2 / 10 in 20.28s
# Finished images 3:4 / 10 in 21.18s
# Finished images 5:6 / 10 in 24.23s
# Finished images 7:8 / 10 in 9.81s
# 1784 + 341 = 2125 ?= 2125
# (tp, fp, fn) = (1784, 901, 341) across 10 images
# Finished iter in 78.10s
#
# Starting conf 0.07
# Finished images 1:2 / 10 in 20.39s
# Finished images 3:4 / 10 in 21.21s
# Finished images 5:6 / 10 in 24.33s
# Finished images 7:8 / 10 in 9.90s
# 1784 + 341 = 2125 ?= 2125
# (tp, fp, fn) = (1784, 901, 341) across 10 images
# Finished iter in 78.46s
#
# Starting conf 0.08
# Finished images 1:2 / 10 in 20.39s
# Finished images 3:4 / 10 in 21.26s
# Finished images 5:6 / 10 in 24.21s
# Finished images 7:8 / 10 in 9.80s
# 1784 + 341 = 2125 ?= 2125
# (tp, fp, fn) = (1784, 901, 341) across 10 images
# Finished iter in 78.24s
#
# Starting conf 0.09
# Finished images 1:2 / 10 in 20.60s
# Finished images 3:4 / 10 in 21.30s
# Finished images 5:6 / 10 in 24.34s
# Finished images 7:8 / 10 in 9.74s
# 1784 + 341 = 2125 ?= 2125
# (tp, fp, fn) = (1784, 901, 341) across 10 images
# Finished iter in 78.62s
#
# Starting conf 0.1
# Finished images 1:2 / 10 in 20.32s
# Finished images 3:4 / 10 in 21.33s
# Finished images 5:6 / 10 in 24.29s
# Finished images 7:8 / 10 in 9.81s
# 1784 + 341 = 2125 ?= 2125
# (tp, fp, fn) = (1784, 901, 341) across 10 images
# Finished iter in 78.28s
#
# Starting conf 0.11
# Finished images 1:2 / 10 in 19.38s
# Finished images 3:4 / 10 in 20.89s
# Finished images 5:6 / 10 in 23.94s
# Finished images 7:8 / 10 in 9.50s
# 1772 + 353 = 2125 ?= 2125
# (tp, fp, fn) = (1772, 913, 353) across 10 images
# Finished iter in 76.27s
#
# Starting conf 0.12
# Finished images 1:2 / 10 in 18.41s
# Finished images 3:4 / 10 in 20.32s
# Finished images 5:6 / 10 in 23.43s
# Finished images 7:8 / 10 in 9.42s
# 1764 + 361 = 2125 ?= 2125
# (tp, fp, fn) = (1764, 921, 361) across 10 images
# Finished iter in 74.06s
#
# Starting conf 0.13
# Finished images 1:2 / 10 in 17.77s
# Finished images 3:4 / 10 in 19.68s
# Finished images 5:6 / 10 in 23.12s
# Finished images 7:8 / 10 in 9.17s
# 1754 + 371 = 2125 ?= 2125
# (tp, fp, fn) = (1754, 931, 371) across 10 images
# Finished iter in 72.23s
#
# Starting conf 0.14
# Finished images 1:2 / 10 in 17.16s
# Finished images 3:4 / 10 in 19.57s
# Finished images 5:6 / 10 in 22.39s
# Finished images 7:8 / 10 in 9.16s
# 1748 + 377 = 2125 ?= 2125
# (tp, fp, fn) = (1748, 937, 377) across 10 images
# Finished iter in 70.71s
#
# Starting conf 0.15
# Finished images 1:2 / 10 in 16.47s
# Finished images 3:4 / 10 in 19.37s
# Finished images 5:6 / 10 in 21.90s
# Finished images 7:8 / 10 in 9.09s
# 1740 + 385 = 2125 ?= 2125
# (tp, fp, fn) = (1740, 945, 385) across 10 images
# Finished iter in 69.25s
#
# Starting conf 0.16
# Finished images 1:2 / 10 in 15.87s
# Finished images 3:4 / 10 in 18.97s
# Finished images 5:6 / 10 in 21.55s
# Finished images 7:8 / 10 in 8.94s
# 1730 + 395 = 2125 ?= 2125
# (tp, fp, fn) = (1730, 955, 395) across 10 images
# Finished iter in 67.69s
#
# Starting conf 0.17
# Finished images 1:2 / 10 in 15.32s
# Finished images 3:4 / 10 in 18.98s
# Finished images 5:6 / 10 in 21.18s
# Finished images 7:8 / 10 in 8.63s
# 1721 + 404 = 2125 ?= 2125
# (tp, fp, fn) = (1721, 964, 404) across 10 images
# Finished iter in 66.44s
#
# Starting conf 0.18
# Finished images 1:2 / 10 in 14.94s
# Finished images 3:4 / 10 in 18.68s
# Finished images 5:6 / 10 in 20.82s
# Finished images 7:8 / 10 in 8.44s
# 1716 + 409 = 2125 ?= 2125
# (tp, fp, fn) = (1716, 969, 409) across 10 images
# Finished iter in 65.16s
#
# Starting conf 0.19
# Finished images 1:2 / 10 in 14.47s
# Finished images 3:4 / 10 in 18.75s
# Finished images 5:6 / 10 in 20.27s
# Finished images 7:8 / 10 in 8.23s
# 1712 + 413 = 2125 ?= 2125
# (tp, fp, fn) = (1712, 973, 413) across 10 images
# Finished iter in 63.93s
#
# Starting conf 0.2
# Finished images 1:2 / 10 in 14.01s
# Finished images 3:4 / 10 in 18.22s
# Finished images 5:6 / 10 in 19.95s
# Finished images 7:8 / 10 in 8.08s
# 1708 + 417 = 2125 ?= 2125
# (tp, fp, fn) = (1708, 977, 417) across 10 images
# Finished iter in 62.43s
#
# Starting conf 0.21
# Finished images 1:2 / 10 in 13.58s
# Finished images 3:4 / 10 in 18.25s
# Finished images 5:6 / 10 in 19.92s
# Finished images 7:8 / 10 in 8.05s
# 1701 + 424 = 2125 ?= 2125
# (tp, fp, fn) = (1701, 984, 424) across 10 images
# Finished iter in 61.93s
#
# Starting conf 0.22
# Finished images 1:2 / 10 in 13.30s
# Finished images 3:4 / 10 in 17.92s
# Finished images 5:6 / 10 in 19.43s
# Finished images 7:8 / 10 in 7.91s
# 1695 + 430 = 2125 ?= 2125
# (tp, fp, fn) = (1695, 990, 430) across 10 images
# Finished iter in 60.63s
#
# Starting conf 0.23
# Finished images 1:2 / 10 in 12.69s
# Finished images 3:4 / 10 in 17.79s
# Finished images 5:6 / 10 in 19.35s
# Finished images 7:8 / 10 in 7.95s
# 1687 + 438 = 2125 ?= 2125
# (tp, fp, fn) = (1687, 998, 438) across 10 images
# Finished iter in 59.83s
#
# Starting conf 0.24
# Finished images 1:2 / 10 in 12.50s
# Finished images 3:4 / 10 in 17.86s
# Finished images 5:6 / 10 in 18.89s
# Finished images 7:8 / 10 in 7.81s
# 1684 + 441 = 2125 ?= 2125
# (tp, fp, fn) = (1684, 1001, 441) across 10 images
# Finished iter in 59.07s
#
# Starting conf 0.25
# Finished images 1:2 / 10 in 12.00s
# Finished images 3:4 / 10 in 17.40s
# Finished images 5:6 / 10 in 18.52s
# Finished images 7:8 / 10 in 7.70s
# 1675 + 450 = 2125 ?= 2125
# (tp, fp, fn) = (1675, 1010, 450) across 10 images
# Finished iter in 57.46s
#
# Starting conf 0.26
# Finished images 1:2 / 10 in 11.55s
# Finished images 3:4 / 10 in 17.28s
# Finished images 5:6 / 10 in 18.44s
# Finished images 7:8 / 10 in 7.59s
# 1668 + 457 = 2125 ?= 2125
# (tp, fp, fn) = (1668, 1017, 457) across 10 images
# Finished iter in 56.68s
#
# Starting conf 0.27
# Finished images 1:2 / 10 in 11.07s
# Finished images 3:4 / 10 in 17.23s
# Finished images 5:6 / 10 in 18.03s
# Finished images 7:8 / 10 in 7.49s
# 1662 + 463 = 2125 ?= 2125
# (tp, fp, fn) = (1662, 1023, 463) across 10 images
# Finished iter in 55.69s
#
# Starting conf 0.28
# Finished images 1:2 / 10 in 10.72s
# Finished images 3:4 / 10 in 16.95s
# Finished images 5:6 / 10 in 17.60s
# Finished images 7:8 / 10 in 7.46s
# 1655 + 470 = 2125 ?= 2125
# (tp, fp, fn) = (1655, 1030, 470) across 10 images
# Finished iter in 54.58s
#
# Starting conf 0.29
# Finished images 1:2 / 10 in 10.27s
# Finished images 3:4 / 10 in 16.88s
# Finished images 5:6 / 10 in 17.44s
# Finished images 7:8 / 10 in 7.32s
# 1650 + 475 = 2125 ?= 2125
# (tp, fp, fn) = (1650, 1035, 475) across 10 images
# Finished iter in 53.75s
#
# Starting conf 0.3
# Finished images 1:2 / 10 in 9.76s
# Finished images 3:4 / 10 in 16.87s
# Finished images 5:6 / 10 in 17.09s
# Finished images 7:8 / 10 in 7.32s
# 1642 + 483 = 2125 ?= 2125
# (tp, fp, fn) = (1642, 1043, 483) across 10 images
# Finished iter in 52.83s
#
# Starting conf 0.31
# Finished images 1:2 / 10 in 9.19s
# Finished images 3:4 / 10 in 16.50s
# Finished images 5:6 / 10 in 16.88s
# Finished images 7:8 / 10 in 7.43s
# 1631 + 494 = 2125 ?= 2125
# (tp, fp, fn) = (1631, 1054, 494) across 10 images
# Finished iter in 51.76s
#
# Starting conf 0.32
# Finished images 1:2 / 10 in 8.81s
# Finished images 3:4 / 10 in 16.52s
# Finished images 5:6 / 10 in 16.41s
# Finished images 7:8 / 10 in 7.44s
# 1617 + 508 = 2125 ?= 2125
# (tp, fp, fn) = (1617, 1068, 508) across 10 images
# Finished iter in 50.90s
#
# Starting conf 0.33
# Finished images 1:2 / 10 in 8.59s
# Finished images 3:4 / 10 in 16.21s
# Finished images 5:6 / 10 in 16.22s
# Finished images 7:8 / 10 in 7.47s
# 1611 + 514 = 2125 ?= 2125
# (tp, fp, fn) = (1611, 1074, 514) across 10 images
# Finished iter in 50.17s
#
# Starting conf 0.34
# Finished images 1:2 / 10 in 8.28s
# Finished images 3:4 / 10 in 16.24s
# Finished images 5:6 / 10 in 16.07s
# Finished images 7:8 / 10 in 7.17s
# 1604 + 521 = 2125 ?= 2125
# (tp, fp, fn) = (1604, 1081, 521) across 10 images
# Finished iter in 49.47s
#
# Starting conf 0.35
# Finished images 1:2 / 10 in 8.17s
# Finished images 3:4 / 10 in 16.12s
# Finished images 5:6 / 10 in 15.99s
# Finished images 7:8 / 10 in 7.05s
# 1591 + 534 = 2125 ?= 2125
# (tp, fp, fn) = (1591, 1094, 534) across 10 images
# Finished iter in 49.05s
#
# Starting conf 0.36
# Finished images 1:2 / 10 in 7.93s
# Finished images 3:4 / 10 in 15.92s
# Finished images 5:6 / 10 in 15.68s
# Finished images 7:8 / 10 in 6.90s
# 1586 + 539 = 2125 ?= 2125
# (tp, fp, fn) = (1586, 1099, 539) across 10 images
# Finished iter in 48.11s
#
# Starting conf 0.37
# Finished images 1:2 / 10 in 7.82s
# Finished images 3:4 / 10 in 15.63s
# Finished images 5:6 / 10 in 15.53s
# Finished images 7:8 / 10 in 6.95s
# 1577 + 548 = 2125 ?= 2125
# (tp, fp, fn) = (1577, 1108, 548) across 10 images
# Finished iter in 47.62s
#
# Starting conf 0.38
# Finished images 1:2 / 10 in 7.53s
# Finished images 3:4 / 10 in 15.62s
# Finished images 5:6 / 10 in 15.18s
# Finished images 7:8 / 10 in 6.76s
# 1569 + 556 = 2125 ?= 2125
# (tp, fp, fn) = (1569, 1116, 556) across 10 images
# Finished iter in 46.73s
#
# Starting conf 0.39
# Finished images 1:2 / 10 in 7.16s
# Finished images 3:4 / 10 in 15.41s
# Finished images 5:6 / 10 in 14.97s
# Finished images 7:8 / 10 in 6.68s
# 1556 + 569 = 2125 ?= 2125
# (tp, fp, fn) = (1556, 1129, 569) across 10 images
# Finished iter in 45.83s
#
# Starting conf 0.4
# Finished images 1:2 / 10 in 6.87s
# Finished images 3:4 / 10 in 15.26s
# Finished images 5:6 / 10 in 14.85s
# Finished images 7:8 / 10 in 6.60s
# 1537 + 588 = 2125 ?= 2125
# (tp, fp, fn) = (1537, 1148, 588) across 10 images
# Finished iter in 45.13s
#
# Starting conf 0.41
# Finished images 1:2 / 10 in 6.61s
# Finished images 3:4 / 10 in 15.01s
# Finished images 5:6 / 10 in 14.24s
# Finished images 7:8 / 10 in 6.57s
# 1524 + 601 = 2125 ?= 2125
# (tp, fp, fn) = (1524, 1161, 601) across 10 images
# Finished iter in 43.91s
#
# Starting conf 0.42
# Finished images 1:2 / 10 in 6.30s
# Finished images 3:4 / 10 in 14.96s
# Finished images 5:6 / 10 in 13.90s
# Finished images 7:8 / 10 in 6.52s
# 1511 + 614 = 2125 ?= 2125
# (tp, fp, fn) = (1511, 1174, 614) across 10 images
# Finished iter in 43.19s
#
# Starting conf 0.43
# Finished images 1:2 / 10 in 6.24s
# Finished images 3:4 / 10 in 15.13s
# Finished images 5:6 / 10 in 13.62s
# Finished images 7:8 / 10 in 6.37s
# 1504 + 621 = 2125 ?= 2125
# (tp, fp, fn) = (1504, 1181, 621) across 10 images
# Finished iter in 42.93s
#
# Starting conf 0.44
# Finished images 1:2 / 10 in 5.89s
# Finished images 3:4 / 10 in 14.62s
# Finished images 5:6 / 10 in 13.32s
# Finished images 7:8 / 10 in 6.38s
# 1498 + 627 = 2125 ?= 2125
# (tp, fp, fn) = (1498, 1187, 627) across 10 images
# Finished iter in 41.76s
#
# Starting conf 0.45
# Finished images 1:2 / 10 in 5.62s
# Finished images 3:4 / 10 in 14.58s
# Finished images 5:6 / 10 in 12.88s
# Finished images 7:8 / 10 in 6.28s
# 1483 + 642 = 2125 ?= 2125
# (tp, fp, fn) = (1483, 1202, 642) across 10 images
# Finished iter in 40.84s
#
# Starting conf 0.46
# Finished images 1:2 / 10 in 5.29s
# Finished images 3:4 / 10 in 14.53s
# Finished images 5:6 / 10 in 12.70s
# Finished images 7:8 / 10 in 6.22s
# 1466 + 659 = 2125 ?= 2125
# (tp, fp, fn) = (1466, 1219, 659) across 10 images
# Finished iter in 40.16s
#
# Starting conf 0.47
# Finished images 1:2 / 10 in 5.30s
# Finished images 3:4 / 10 in 14.49s
# Finished images 5:6 / 10 in 12.49s
# Finished images 7:8 / 10 in 6.28s
# 1450 + 675 = 2125 ?= 2125
# (tp, fp, fn) = (1450, 1235, 675) across 10 images
# Finished iter in 40.00s
#
# Starting conf 0.48
# Finished images 1:2 / 10 in 5.01s
# Finished images 3:4 / 10 in 14.23s
# Finished images 5:6 / 10 in 12.24s
# Finished images 7:8 / 10 in 6.18s
# 1434 + 691 = 2125 ?= 2125
# (tp, fp, fn) = (1434, 1251, 691) across 10 images
# Finished iter in 39.10s
#
# Starting conf 0.49
# Finished images 1:2 / 10 in 4.91s
# Finished images 3:4 / 10 in 14.15s
# Finished images 5:6 / 10 in 12.20s
# Finished images 7:8 / 10 in 6.27s
# 1422 + 703 = 2125 ?= 2125
# (tp, fp, fn) = (1422, 1263, 703) across 10 images
# Finished iter in 38.96s
#
# Starting conf 0.5
# Finished images 1:2 / 10 in 4.62s
# Finished images 3:4 / 10 in 14.08s
# Finished images 5:6 / 10 in 12.01s
# Finished images 7:8 / 10 in 6.11s
# 1411 + 714 = 2125 ?= 2125
# (tp, fp, fn) = (1411, 1274, 714) across 10 images
# Finished iter in 38.24s
#
# Starting conf 0.51
# Finished images 1:2 / 10 in 4.48s
# Finished images 3:4 / 10 in 13.88s
# Finished images 5:6 / 10 in 11.79s
# Finished images 7:8 / 10 in 6.08s
# 1396 + 729 = 2125 ?= 2125
# (tp, fp, fn) = (1396, 1289, 729) across 10 images
# Finished iter in 37.66s
#
# Starting conf 0.52
# Finished images 1:2 / 10 in 4.33s
# Finished images 3:4 / 10 in 13.59s
# Finished images 5:6 / 10 in 11.72s
# Finished images 7:8 / 10 in 6.02s
# 1380 + 745 = 2125 ?= 2125
# (tp, fp, fn) = (1380, 1305, 745) across 10 images
# Finished iter in 37.09s
#
# Starting conf 0.53
# Finished images 1:2 / 10 in 4.34s
# Finished images 3:4 / 10 in 13.59s
# Finished images 5:6 / 10 in 11.67s
# Finished images 7:8 / 10 in 5.97s
# 1360 + 765 = 2125 ?= 2125
# (tp, fp, fn) = (1360, 1325, 765) across 10 images
# Finished iter in 36.94s
#
# Starting conf 0.54
# Finished images 1:2 / 10 in 4.10s
# Finished images 3:4 / 10 in 13.03s
# Finished images 5:6 / 10 in 11.25s
# Finished images 7:8 / 10 in 5.92s
# 1328 + 797 = 2125 ?= 2125
# (tp, fp, fn) = (1328, 1357, 797) across 10 images
# Finished iter in 35.65s
#
# Starting conf 0.55
# Finished images 1:2 / 10 in 4.04s
# Finished images 3:4 / 10 in 12.95s
# Finished images 5:6 / 10 in 11.09s
# Finished images 7:8 / 10 in 5.90s
# 1305 + 820 = 2125 ?= 2125
# (tp, fp, fn) = (1305, 1380, 820) across 10 images
# Finished iter in 35.31s
#
# Starting conf 0.56
# Finished images 1:2 / 10 in 3.76s
# Finished images 3:4 / 10 in 12.93s
# Finished images 5:6 / 10 in 10.90s
# Finished images 7:8 / 10 in 5.84s
# 1276 + 849 = 2125 ?= 2125
# (tp, fp, fn) = (1276, 1409, 849) across 10 images
# Finished iter in 34.73s
#
# Starting conf 0.57
# Finished images 1:2 / 10 in 3.28s
# Finished images 3:4 / 10 in 12.70s
# Finished images 5:6 / 10 in 10.84s
# Finished images 7:8 / 10 in 5.69s
# 1244 + 881 = 2125 ?= 2125
# (tp, fp, fn) = (1244, 1441, 881) across 10 images
# Finished iter in 33.87s
#
# Starting conf 0.58
# Finished images 1:2 / 10 in 3.18s
# Finished images 3:4 / 10 in 12.67s
# Finished images 5:6 / 10 in 10.58s
# Finished images 7:8 / 10 in 5.65s
# 1228 + 897 = 2125 ?= 2125
# (tp, fp, fn) = (1228, 1457, 897) across 10 images
# Finished iter in 33.38s
#
# Starting conf 0.59
# Finished images 1:2 / 10 in 3.18s
# Finished images 3:4 / 10 in 12.55s
# Finished images 5:6 / 10 in 10.35s
# Finished images 7:8 / 10 in 5.62s
# 1205 + 920 = 2125 ?= 2125
# (tp, fp, fn) = (1205, 1480, 920) across 10 images
# Finished iter in 32.97s
#
# Starting conf 0.6
# Finished images 1:2 / 10 in 3.08s
# Finished images 3:4 / 10 in 12.52s
# Finished images 5:6 / 10 in 10.10s
# Finished images 7:8 / 10 in 5.56s
# 1170 + 955 = 2125 ?= 2125
# (tp, fp, fn) = (1170, 1515, 955) across 10 images
# Finished iter in 32.46s
#
# Starting conf 0.61
# Finished images 1:2 / 10 in 2.80s
# Finished images 3:4 / 10 in 12.12s
# Finished images 5:6 / 10 in 9.73s
# Finished images 7:8 / 10 in 5.43s
# 1134 + 991 = 2125 ?= 2125
# (tp, fp, fn) = (1134, 1551, 991) across 10 images
# Finished iter in 31.26s
#
# Starting conf 0.62
# Finished images 1:2 / 10 in 2.80s
# Finished images 3:4 / 10 in 11.95s
# Finished images 5:6 / 10 in 9.43s
# Finished images 7:8 / 10 in 5.30s
# 1097 + 1028 = 2125 ?= 2125
# (tp, fp, fn) = (1097, 1588, 1028) across 10 images
# Finished iter in 30.64s
#
# Starting conf 0.63
# Finished images 1:2 / 10 in 2.66s
# Finished images 3:4 / 10 in 11.93s
# Finished images 5:6 / 10 in 9.30s
# Finished images 7:8 / 10 in 5.25s
# 1064 + 1061 = 2125 ?= 2125
# (tp, fp, fn) = (1064, 1621, 1061) across 10 images
# Finished iter in 30.23s
#
# Starting conf 0.64
# Finished images 1:2 / 10 in 2.52s
# Finished images 3:4 / 10 in 11.77s
# Finished images 5:6 / 10 in 9.12s
# Finished images 7:8 / 10 in 5.22s
# 1029 + 1096 = 2125 ?= 2125
# (tp, fp, fn) = (1029, 1656, 1096) across 10 images
# Finished iter in 29.66s
#
# Starting conf 0.65
# Finished images 1:2 / 10 in 2.35s
# Finished images 3:4 / 10 in 11.62s
# Finished images 5:6 / 10 in 8.94s
# Finished images 7:8 / 10 in 5.04s
# 995 + 1130 = 2125 ?= 2125
# (tp, fp, fn) = (995, 1690, 1130) across 10 images
# Finished iter in 28.98s
#
# Starting conf 0.66
# Finished images 1:2 / 10 in 2.25s
# Finished images 3:4 / 10 in 11.41s
# Finished images 5:6 / 10 in 8.36s
# Finished images 7:8 / 10 in 4.88s
# 954 + 1171 = 2125 ?= 2125
# (tp, fp, fn) = (954, 1731, 1171) across 10 images
# Finished iter in 27.93s
#
# Starting conf 0.67
# Finished images 1:2 / 10 in 2.15s
# Finished images 3:4 / 10 in 11.00s
# Finished images 5:6 / 10 in 8.38s
# Finished images 7:8 / 10 in 4.81s
# 915 + 1210 = 2125 ?= 2125
# (tp, fp, fn) = (915, 1770, 1210) across 10 images
# Finished iter in 27.31s
#
# Starting conf 0.68
# Finished images 1:2 / 10 in 1.89s
# Finished images 3:4 / 10 in 10.85s
# Finished images 5:6 / 10 in 8.38s
# Finished images 7:8 / 10 in 4.71s
# 867 + 1258 = 2125 ?= 2125
# (tp, fp, fn) = (867, 1818, 1258) across 10 images
# Finished iter in 26.75s
#
# Starting conf 0.69
# Finished images 1:2 / 10 in 1.73s
# Finished images 3:4 / 10 in 10.59s
# Finished images 5:6 / 10 in 7.92s
# Finished images 7:8 / 10 in 4.69s
# 829 + 1296 = 2125 ?= 2125
# (tp, fp, fn) = (829, 1856, 1296) across 10 images
# Finished iter in 25.77s
#
# Starting conf 0.7
# Finished images 1:2 / 10 in 1.55s
# Finished images 3:4 / 10 in 10.25s
# Finished images 5:6 / 10 in 7.45s
# Finished images 7:8 / 10 in 4.60s
# 782 + 1343 = 2125 ?= 2125
# (tp, fp, fn) = (782, 1903, 1343) across 10 images
# Finished iter in 24.71s
#
# Starting conf 0.71
# Finished images 1:2 / 10 in 1.35s
# Finished images 3:4 / 10 in 9.95s
# Finished images 5:6 / 10 in 7.24s
# Finished images 7:8 / 10 in 4.62s
# 733 + 1392 = 2125 ?= 2125
# (tp, fp, fn) = (733, 1952, 1392) across 10 images
# Finished iter in 24.00s
#
# Starting conf 0.72
# Finished images 1:2 / 10 in 1.26s
# Finished images 3:4 / 10 in 9.50s
# Finished images 5:6 / 10 in 6.74s
# Finished images 7:8 / 10 in 4.53s
# 698 + 1427 = 2125 ?= 2125
# (tp, fp, fn) = (698, 1987, 1427) across 10 images
# Finished iter in 22.82s
#
# Starting conf 0.73
# Finished images 1:2 / 10 in 1.21s
# Finished images 3:4 / 10 in 9.32s
# Finished images 5:6 / 10 in 6.50s
# Finished images 7:8 / 10 in 4.42s
# 668 + 1457 = 2125 ?= 2125
# (tp, fp, fn) = (668, 2017, 1457) across 10 images
# Finished iter in 22.25s
#
# Starting conf 0.74
# Finished images 1:2 / 10 in 1.08s
# Finished images 3:4 / 10 in 8.77s
# Finished images 5:6 / 10 in 5.94s
# Finished images 7:8 / 10 in 4.29s
# 635 + 1490 = 2125 ?= 2125
# (tp, fp, fn) = (635, 2050, 1490) across 10 images
# Finished iter in 20.88s
#
# Starting conf 0.75
# Finished images 1:2 / 10 in 1.02s
# Finished images 3:4 / 10 in 8.38s
# Finished images 5:6 / 10 in 5.56s
# Finished images 7:8 / 10 in 4.18s
# 597 + 1528 = 2125 ?= 2125
# (tp, fp, fn) = (597, 2088, 1528) across 10 images
# Finished iter in 19.89s
#
# Starting conf 0.76
# Finished images 1:2 / 10 in 0.90s
# Finished images 3:4 / 10 in 7.99s
# Finished images 5:6 / 10 in 5.35s
# Finished images 7:8 / 10 in 3.90s
# 559 + 1566 = 2125 ?= 2125
# (tp, fp, fn) = (559, 2126, 1566) across 10 images
# Finished iter in 18.85s
#
# Starting conf 0.77
# Finished images 1:2 / 10 in 0.88s
# Finished images 3:4 / 10 in 7.47s
# Finished images 5:6 / 10 in 5.20s
# Finished images 7:8 / 10 in 3.65s
# 527 + 1598 = 2125 ?= 2125
# (tp, fp, fn) = (527, 2158, 1598) across 10 images
# Finished iter in 17.93s
#
# Starting conf 0.78
# Finished images 1:2 / 10 in 0.78s
# Finished images 3:4 / 10 in 7.24s
# Finished images 5:6 / 10 in 4.92s
# Finished images 7:8 / 10 in 3.52s
# 499 + 1626 = 2125 ?= 2125
# (tp, fp, fn) = (499, 2186, 1626) across 10 images
# Finished iter in 17.17s
#
# Starting conf 0.79
# Finished images 1:2 / 10 in 0.74s
# Finished images 3:4 / 10 in 6.70s
# Finished images 5:6 / 10 in 4.44s
# Finished images 7:8 / 10 in 3.37s
# 463 + 1662 = 2125 ?= 2125
# (tp, fp, fn) = (463, 2222, 1662) across 10 images
# Finished iter in 15.96s
#
# Starting conf 0.8
# Finished images 1:2 / 10 in 0.68s
# Finished images 3:4 / 10 in 6.32s
# Finished images 5:6 / 10 in 4.11s
# Finished images 7:8 / 10 in 3.12s
# 428 + 1697 = 2125 ?= 2125
# (tp, fp, fn) = (428, 2257, 1697) across 10 images
# Finished iter in 14.91s
#
# Starting conf 0.81
# Finished images 1:2 / 10 in 0.64s
# Finished images 3:4 / 10 in 6.08s
# Finished images 5:6 / 10 in 4.06s
# Finished images 7:8 / 10 in 2.98s
# 402 + 1723 = 2125 ?= 2125
# (tp, fp, fn) = (402, 2283, 1723) across 10 images
# Finished iter in 14.46s
#
# Starting conf 0.82
# Finished images 1:2 / 10 in 0.58s
# Finished images 3:4 / 10 in 5.84s
# Finished images 5:6 / 10 in 3.75s
# Finished images 7:8 / 10 in 2.75s
# 378 + 1747 = 2125 ?= 2125
# (tp, fp, fn) = (378, 2307, 1747) across 10 images
# Finished iter in 13.57s
#
# Starting conf 0.83
# Finished images 1:2 / 10 in 0.51s
# Finished images 3:4 / 10 in 5.46s
# Finished images 5:6 / 10 in 3.30s
# Finished images 7:8 / 10 in 2.58s
# 341 + 1784 = 2125 ?= 2125
# (tp, fp, fn) = (341, 2344, 1784) across 10 images
# Finished iter in 12.50s
#
# Starting conf 0.84
# Finished images 1:2 / 10 in 0.44s
# Finished images 3:4 / 10 in 5.14s
# Finished images 5:6 / 10 in 3.00s
# Finished images 7:8 / 10 in 2.21s
# 306 + 1819 = 2125 ?= 2125
# (tp, fp, fn) = (306, 2379, 1819) across 10 images
# Finished iter in 11.36s
#
# Starting conf 0.85
# Finished images 1:2 / 10 in 0.39s
# Finished images 3:4 / 10 in 4.68s
# Finished images 5:6 / 10 in 2.61s
# Finished images 7:8 / 10 in 2.07s
# 278 + 1847 = 2125 ?= 2125
# (tp, fp, fn) = (278, 2407, 1847) across 10 images
# Finished iter in 10.31s
#
# Starting conf 0.86
# Finished images 1:2 / 10 in 0.37s
# Finished images 3:4 / 10 in 4.36s
# Finished images 5:6 / 10 in 2.34s
# Finished images 7:8 / 10 in 1.99s
# 251 + 1874 = 2125 ?= 2125
# (tp, fp, fn) = (251, 2434, 1874) across 10 images
# Finished iter in 9.56s
#
# Starting conf 0.87
# Finished images 1:2 / 10 in 0.33s
# Finished images 3:4 / 10 in 3.94s
# Finished images 5:6 / 10 in 2.13s
# Finished images 7:8 / 10 in 1.82s
# 225 + 1900 = 2125 ?= 2125
# (tp, fp, fn) = (225, 2460, 1900) across 10 images
# Finished iter in 8.69s
#
# Starting conf 0.88
# Finished images 1:2 / 10 in 0.19s
# Finished images 3:4 / 10 in 3.58s
# Finished images 5:6 / 10 in 1.82s
# Finished images 7:8 / 10 in 1.67s
# 201 + 1924 = 2125 ?= 2125
# (tp, fp, fn) = (201, 2484, 1924) across 10 images
# Finished iter in 7.69s
#
# Starting conf 0.89
# Finished images 1:2 / 10 in 0.18s
# Finished images 3:4 / 10 in 3.07s
# Finished images 5:6 / 10 in 1.45s
# Finished images 7:8 / 10 in 1.58s
# 173 + 1952 = 2125 ?= 2125
# (tp, fp, fn) = (173, 2512, 1952) across 10 images
# Finished iter in 6.61s
#
# Starting conf 0.9
# Finished images 1:2 / 10 in 0.18s
# Finished images 3:4 / 10 in 2.62s
# Finished images 5:6 / 10 in 1.17s
# Finished images 7:8 / 10 in 1.36s
# 145 + 1980 = 2125 ?= 2125
# (tp, fp, fn) = (145, 2540, 1980) across 10 images
# Finished iter in 5.62s
#
# Starting conf 0.91
# Finished images 1:2 / 10 in 0.17s
# Finished images 3:4 / 10 in 2.38s
# Finished images 5:6 / 10 in 0.72s
# Finished images 7:8 / 10 in 1.35s
# 127 + 1998 = 2125 ?= 2125
# (tp, fp, fn) = (127, 2558, 1998) across 10 images
# Finished iter in 4.83s
#
# Starting conf 0.92
# Finished images 1:2 / 10 in 0.15s
# Finished images 3:4 / 10 in 2.04s
# Finished images 5:6 / 10 in 0.60s
# Finished images 7:8 / 10 in 1.18s
# 105 + 2020 = 2125 ?= 2125
# (tp, fp, fn) = (105, 2580, 2020) across 10 images
# Finished iter in 4.13s
#
# Starting conf 0.93
# Finished images 1:2 / 10 in 0.13s
# Finished images 3:4 / 10 in 1.75s
# Finished images 5:6 / 10 in 0.46s
# Finished images 7:8 / 10 in 1.09s
# 86 + 2039 = 2125 ?= 2125
# (tp, fp, fn) = (86, 2599, 2039) across 10 images
# Finished iter in 3.59s
#
# Starting conf 0.94
# Finished images 1:2 / 10 in 0.12s
# Finished images 3:4 / 10 in 1.41s
# Finished images 5:6 / 10 in 0.42s
# Finished images 7:8 / 10 in 0.78s
# 67 + 2058 = 2125 ?= 2125
# (tp, fp, fn) = (67, 2618, 2058) across 10 images
# Finished iter in 2.86s
#
# Starting conf 0.95
# Finished images 1:2 / 10 in 0.10s
# Finished images 3:4 / 10 in 0.74s
# Finished images 5:6 / 10 in 0.25s
# Finished images 7:8 / 10 in 0.37s
# 34 + 2091 = 2125 ?= 2125
# (tp, fp, fn) = (34, 2651, 2091) across 10 images
# Finished iter in 1.52s
#
# Starting conf 0.96
# Finished images 1:2 / 10 in 0.13s
# Finished images 3:4 / 10 in 0.19s
# Finished images 5:6 / 10 in 0.09s
# Finished images 7:8 / 10 in 0.17s
# 18 + 2107 = 2125 ?= 2125
# (tp, fp, fn) = (18, 2667, 2107) across 10 images
# Finished iter in 0.61s
#
# Starting conf 0.97
# Finished images 1:2 / 10 in 0.05s
# Finished images 3:4 / 10 in 0.00s
# Finished images 5:6 / 10 in 0.01s
# Finished images 7:8 / 10 in 0.05s
# 8 + 2117 = 2125 ?= 2125
# (tp, fp, fn) = (8, 2677, 2117) across 10 images
# Finished iter in 0.15s
#
# Starting conf 0.98
# Finished images 1:2 / 10 in 0.08s
# Finished images 3:4 / 10 in 0.00s
# Finished images 5:6 / 10 in 0.00s
# Finished images 7:8 / 10 in 0.00s
# 5 + 2120 = 2125 ?= 2125
# (tp, fp, fn) = (5, 2680, 2120) across 10 images
# Finished iter in 0.12s
#
# Starting conf 0.99
# Finished images 1:2 / 10 in 0.00s
# Finished images 3:4 / 10 in 0.00s
# Finished images 5:6 / 10 in 0.00s
# Finished images 7:8 / 10 in 0.00s
# 0 + 2125 = 2125 ?= 2125
# (tp, fp, fn) = (0, 2685, 2125) across 10 images
# Finished iter in 0.02s
#
# Finished iou 0.5 in 3883.87s
# ===== Starting iou 0.55 =====
# Starting conf 0.01
# Finished images 1:2 / 10 in 22.05s
# Finished images 3:4 / 10 in 21.73s
# Finished images 5:6 / 10 in 25.96s
# Finished images 7:8 / 10 in 10.14s
# 1715 + 410 = 2125 ?= 2125
# (tp, fp, fn) = (1715, 970, 410) across 10 images
# Finished iter in 82.50s
#
# Starting conf 0.02
# Finished images 1:2 / 10 in 22.03s
# Finished images 3:4 / 10 in 21.91s
# Finished images 5:6 / 10 in 25.81s
# Finished images 7:8 / 10 in 10.27s
# 1715 + 410 = 2125 ?= 2125
# (tp, fp, fn) = (1715, 970, 410) across 10 images
# Finished iter in 82.59s
#
# Starting conf 0.03
# Finished images 1:2 / 10 in 21.93s
# Finished images 3:4 / 10 in 21.74s
# Finished images 5:6 / 10 in 25.88s
# Finished images 7:8 / 10 in 10.11s
# 1715 + 410 = 2125 ?= 2125
# (tp, fp, fn) = (1715, 970, 410) across 10 images
# Finished iter in 82.35s
#
# Starting conf 0.04
# Finished images 1:2 / 10 in 22.06s
# Finished images 3:4 / 10 in 21.75s
# Finished images 5:6 / 10 in 25.88s
# Finished images 7:8 / 10 in 10.13s
# 1715 + 410 = 2125 ?= 2125
# (tp, fp, fn) = (1715, 970, 410) across 10 images
# Finished iter in 82.40s
#
# Starting conf 0.05
# Finished images 1:2 / 10 in 22.02s
# Finished images 3:4 / 10 in 21.83s
# Finished images 5:6 / 10 in 25.91s
# Finished images 7:8 / 10 in 10.12s
# 1715 + 410 = 2125 ?= 2125
# (tp, fp, fn) = (1715, 970, 410) across 10 images
# Finished iter in 82.51s
#
# Starting conf 0.06
# Finished images 1:2 / 10 in 22.07s
# Finished images 3:4 / 10 in 21.78s
# Finished images 5:6 / 10 in 25.77s
# Finished images 7:8 / 10 in 10.21s
# 1715 + 410 = 2125 ?= 2125
# (tp, fp, fn) = (1715, 970, 410) across 10 images
# Finished iter in 82.47s
#
# Starting conf 0.07
# Finished images 1:2 / 10 in 22.04s
# Finished images 3:4 / 10 in 21.73s
# Finished images 5:6 / 10 in 25.92s
# Finished images 7:8 / 10 in 10.19s
# 1715 + 410 = 2125 ?= 2125
# (tp, fp, fn) = (1715, 970, 410) across 10 images
# Finished iter in 82.45s
#
# Starting conf 0.08
# Finished images 1:2 / 10 in 22.08s
# Finished images 3:4 / 10 in 21.94s
# Finished images 5:6 / 10 in 25.83s
# Finished images 7:8 / 10 in 10.12s
# 1715 + 410 = 2125 ?= 2125
# (tp, fp, fn) = (1715, 970, 410) across 10 images
# Finished iter in 82.59s
#
# Starting conf 0.09
# Finished images 1:2 / 10 in 21.90s
# Finished images 3:4 / 10 in 21.73s
# Finished images 5:6 / 10 in 25.84s
# Finished images 7:8 / 10 in 10.10s
# 1715 + 410 = 2125 ?= 2125
# (tp, fp, fn) = (1715, 970, 410) across 10 images
# Finished iter in 82.22s
#
# Starting conf 0.1
# Finished images 1:2 / 10 in 21.95s
# Finished images 3:4 / 10 in 21.72s
# Finished images 5:6 / 10 in 25.82s
# Finished images 7:8 / 10 in 10.09s
# 1715 + 410 = 2125 ?= 2125
# (tp, fp, fn) = (1715, 970, 410) across 10 images
# Finished iter in 82.20s
#
# Starting conf 0.11
# Finished images 1:2 / 10 in 20.99s
# Finished images 3:4 / 10 in 21.33s
# Finished images 5:6 / 10 in 25.76s
# Finished images 7:8 / 10 in 9.84s
# 1702 + 423 = 2125 ?= 2125
# (tp, fp, fn) = (1702, 983, 423) across 10 images
# Finished iter in 80.49s
#
# Starting conf 0.12
# Finished images 1:2 / 10 in 19.74s
# Finished images 3:4 / 10 in 20.82s
# Finished images 5:6 / 10 in 25.09s
# Finished images 7:8 / 10 in 9.78s
# 1696 + 429 = 2125 ?= 2125
# (tp, fp, fn) = (1696, 989, 429) across 10 images
# Finished iter in 77.89s
#
# Starting conf 0.13
# Finished images 1:2 / 10 in 19.23s
# Finished images 3:4 / 10 in 20.30s
# Finished images 5:6 / 10 in 24.73s
# Finished images 7:8 / 10 in 9.49s
# 1686 + 439 = 2125 ?= 2125
# (tp, fp, fn) = (1686, 999, 439) across 10 images
# Finished iter in 76.22s
#
# Starting conf 0.14
# Finished images 1:2 / 10 in 18.52s
# Finished images 3:4 / 10 in 20.12s
# Finished images 5:6 / 10 in 24.13s
# Finished images 7:8 / 10 in 9.38s
# 1681 + 444 = 2125 ?= 2125
# (tp, fp, fn) = (1681, 1004, 444) across 10 images
# Finished iter in 74.63s
#
# Starting conf 0.15
# Finished images 1:2 / 10 in 17.85s
# Finished images 3:4 / 10 in 19.74s
# Finished images 5:6 / 10 in 23.44s
# Finished images 7:8 / 10 in 9.26s
# 1674 + 451 = 2125 ?= 2125
# (tp, fp, fn) = (1674, 1011, 451) across 10 images
# Finished iter in 72.74s
#
# Starting conf 0.16
# Finished images 1:2 / 10 in 17.10s
# Finished images 3:4 / 10 in 19.53s
# Finished images 5:6 / 10 in 23.13s
# Finished images 7:8 / 10 in 9.14s
# 1666 + 459 = 2125 ?= 2125
# (tp, fp, fn) = (1666, 1019, 459) across 10 images
# Finished iter in 71.27s
#
# Starting conf 0.17
# Finished images 1:2 / 10 in 16.50s
# Finished images 3:4 / 10 in 19.44s
# Finished images 5:6 / 10 in 22.76s
# Finished images 7:8 / 10 in 8.94s
# 1658 + 467 = 2125 ?= 2125
# (tp, fp, fn) = (1658, 1027, 467) across 10 images
# Finished iter in 70.05s
#
# Starting conf 0.18
# Finished images 1:2 / 10 in 16.10s
# Finished images 3:4 / 10 in 19.36s
# Finished images 5:6 / 10 in 22.41s
# Finished images 7:8 / 10 in 8.75s
# 1654 + 471 = 2125 ?= 2125
# (tp, fp, fn) = (1654, 1031, 471) across 10 images
# Finished iter in 68.94s
#
# Starting conf 0.19
# Finished images 1:2 / 10 in 15.60s
# Finished images 3:4 / 10 in 19.15s
# Finished images 5:6 / 10 in 21.77s
# Finished images 7:8 / 10 in 8.54s
# 1650 + 475 = 2125 ?= 2125
# (tp, fp, fn) = (1650, 1035, 475) across 10 images
# Finished iter in 67.32s
#
# Starting conf 0.2
# Finished images 1:2 / 10 in 15.09s
# Finished images 3:4 / 10 in 18.66s
# Finished images 5:6 / 10 in 21.41s
# Finished images 7:8 / 10 in 8.48s
# 1646 + 479 = 2125 ?= 2125
# (tp, fp, fn) = (1646, 1039, 479) across 10 images
# Finished iter in 65.85s
#
# Starting conf 0.21
# Finished images 1:2 / 10 in 14.59s
# Finished images 3:4 / 10 in 18.55s
# Finished images 5:6 / 10 in 21.25s
# Finished images 7:8 / 10 in 8.29s
# 1640 + 485 = 2125 ?= 2125
# (tp, fp, fn) = (1640, 1045, 485) across 10 images
# Finished iter in 64.93s
#
# Starting conf 0.22
# Finished images 1:2 / 10 in 14.24s
# Finished images 3:4 / 10 in 18.30s
# Finished images 5:6 / 10 in 20.88s
# Finished images 7:8 / 10 in 8.12s
# 1636 + 489 = 2125 ?= 2125
# (tp, fp, fn) = (1636, 1049, 489) across 10 images
# Finished iter in 63.68s
#
# Starting conf 0.23
# Finished images 1:2 / 10 in 13.57s
# Finished images 3:4 / 10 in 18.24s
# Finished images 5:6 / 10 in 20.52s
# Finished images 7:8 / 10 in 8.17s
# 1630 + 495 = 2125 ?= 2125
# (tp, fp, fn) = (1630, 1055, 495) across 10 images
# Finished iter in 62.65s
#
# Starting conf 0.24
# Finished images 1:2 / 10 in 13.23s
# Finished images 3:4 / 10 in 18.07s
# Finished images 5:6 / 10 in 20.23s
# Finished images 7:8 / 10 in 7.99s
# 1628 + 497 = 2125 ?= 2125
# (tp, fp, fn) = (1628, 1057, 497) across 10 images
# Finished iter in 61.56s
#
# Starting conf 0.25
# Finished images 1:2 / 10 in 12.73s
# Finished images 3:4 / 10 in 17.81s
# Finished images 5:6 / 10 in 19.73s
# Finished images 7:8 / 10 in 7.88s
# 1621 + 504 = 2125 ?= 2125
# (tp, fp, fn) = (1621, 1064, 504) across 10 images
# Finished iter in 60.15s
#
# Starting conf 0.26
# Finished images 1:2 / 10 in 12.47s
# Finished images 3:4 / 10 in 17.76s
# Finished images 5:6 / 10 in 19.84s
# Finished images 7:8 / 10 in 7.79s
# 1613 + 512 = 2125 ?= 2125
# (tp, fp, fn) = (1613, 1072, 512) across 10 images
# Finished iter in 59.79s
#
# Starting conf 0.27
# Finished images 1:2 / 10 in 11.83s
# Finished images 3:4 / 10 in 17.75s
# Finished images 5:6 / 10 in 19.39s
# Finished images 7:8 / 10 in 7.79s
# 1606 + 519 = 2125 ?= 2125
# (tp, fp, fn) = (1606, 1079, 519) across 10 images
# Finished iter in 58.69s
#
# Starting conf 0.28
# Finished images 1:2 / 10 in 11.53s
# Finished images 3:4 / 10 in 17.57s
# Finished images 5:6 / 10 in 18.94s
# Finished images 7:8 / 10 in 7.67s
# 1600 + 525 = 2125 ?= 2125
# (tp, fp, fn) = (1600, 1085, 525) across 10 images
# Finished iter in 57.61s
#
# Starting conf 0.29
# Finished images 1:2 / 10 in 11.10s
# Finished images 3:4 / 10 in 17.31s
# Finished images 5:6 / 10 in 18.81s
# Finished images 7:8 / 10 in 7.50s
# 1595 + 530 = 2125 ?= 2125
# (tp, fp, fn) = (1595, 1090, 530) across 10 images
# Finished iter in 56.57s
#
# Starting conf 0.3
# Finished images 1:2 / 10 in 10.51s
# Finished images 3:4 / 10 in 17.44s
# Finished images 5:6 / 10 in 18.65s
# Finished images 7:8 / 10 in 7.59s
# 1586 + 539 = 2125 ?= 2125
# (tp, fp, fn) = (1586, 1099, 539) across 10 images
# Finished iter in 56.05s
#
# Starting conf 0.31
# Finished images 1:2 / 10 in 9.97s
# Finished images 3:4 / 10 in 17.12s
# Finished images 5:6 / 10 in 18.18s
# Finished images 7:8 / 10 in 7.46s
# 1578 + 547 = 2125 ?= 2125
# (tp, fp, fn) = (1578, 1107, 547) across 10 images
# Finished iter in 54.56s
#
# Starting conf 0.32
# Finished images 1:2 / 10 in 9.47s
# Finished images 3:4 / 10 in 16.96s
# Finished images 5:6 / 10 in 17.67s
# Finished images 7:8 / 10 in 7.44s
# 1567 + 558 = 2125 ?= 2125
# (tp, fp, fn) = (1567, 1118, 558) across 10 images
# Finished iter in 53.31s
#
# Starting conf 0.33
# Finished images 1:2 / 10 in 9.20s

# %%
total = 0
for i, gt_bb in enumerate(all_pred_bbox):
    total += len(gt_bb)
    print(i,':',len(gt_bb))
print(total)
